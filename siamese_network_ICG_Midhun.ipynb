# %% [markdown]
# # Siamese Network
# Network for a Face Recognition System

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import cv2
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import resnet
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Utility Functions

# %%
# Function to generate image pairs
def generate_image_pairs(images, labels):
    # Generate index for each label
    unique_labels = np.unique(labels)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels) if
                                       label == curr_label])

    # Generate image pairs and labels
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images):
        pos_indices = label_wise_indices.get(labels[index])
        pos_image = images[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels != labels[index])
        neg_image = images[np.random.choice(neg_indices[0])]
        pair_images.append((image, neg_image))
        pair_labels.append(0)

    return np.array(pair_images), np.array(pair_labels)

# %% [markdown]
# ## Prepare Data

# %%
from sklearn.datasets import fetch_olivetti_faces

# Import the sklearn olivetti faces dataset
data = fetch_olivetti_faces()
images = data.images
labels = data.target
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data

# %%
# Load the images and labels
face_images = images
face_labels = labels

# %%
target_shape = face_images[0].shape

# %%
images_dataset, labels_dataset = generate_image_pairs(face_images, face_labels)
images_dataset, labels_dataset = shuffle(images_dataset, labels_dataset)

# %% [markdown]
# ## Visualize

# %%
def visualize(image_pairs, labels, n = 5, title = "Image Pair Examples"):
    """ Visualize a few pairs """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    plt.title(title)
    axs = fig.subplots(n, 2)
    for i in range(n):
        show(axs[i, 0], image_pairs[i][0])
        show(axs[i, 1], image_pairs[i][1])

# %%
# Visualize Positive Images
n = 5
indices = np.where(labels_dataset == 1)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Positive Image Examples")

# %%
# Visualize Negative Images
n = 5
indices = np.where(labels_dataset == 0)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Negative Image Examples")

# %% [markdown]
# # Network Architecture

# %% [markdown]
# ## Embedding Layer

# %%
inputs = layers.Input((64, 64, 1))

x = layers.Conv2D(64, (10, 10), padding="same", activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (7, 7), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (4, 4), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(256, (4, 4), padding="same", activation="relu")(x)
fcOutput = layers.Flatten()(x)
fcOutput = layers.Dense(4096, activation = "relu")(fcOutput)
outputs = layers.Dense(1024, activation = "sigmoid")(fcOutput)

embedding = Model(inputs, outputs, name = "Embedding")
# Out:
# 2022-01-27 08:30:02.772388: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:02.907546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:02.908319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:02.909473: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-27 08:30:02.910485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:02.911151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:02.911759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:04.987213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:04.988053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:04.988820: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-27 08:30:04.989407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ## Siamese Network

# %%
import tensorflow.keras.backend as K

# %%
# Define the Contrastive Loss
def contrastive_loss(y, preds, margin=1):
    y = tf.cast(y, preds.dtype)
    squaredPreds = K.square(preds)
    squaredMargin = K.square(K.maximum(margin - preds, 0))
    loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)

    return loss

# %%
# Distance Layer
class DistanceLayer(layers.Layer):
    """
    This layer is responsible for computing the distance
    between the embeddings
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, compare):
        sum_squared = K.sum(K.square(anchor - compare), axis=1, keepdims=True)
        return K.sqrt(K.maximum(sum_squared, K.epsilon()))

# %%
anchor_input = layers.Input(name="anchor", shape=target_shape + (1,))
compare_input = layers.Input(name="compare", shape=target_shape + (1,))

distances = DistanceLayer()(
    embedding(anchor_input),
    embedding(compare_input),
)

outputs = layers.Dense(1, activation = "sigmoid") (distances)

siamese_model = Model(
    inputs=[anchor_input, compare_input], outputs=outputs
)

# %% [markdown]
# # Training

# %%
siamese_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
history = siamese_model.fit([images_dataset[:, 0, :], images_dataset[:, 1, :]], labels_dataset,
                            epochs=150, validation_split = 0.2, batch_size = 64)
# Out:
# 2022-01-27 08:30:06.568940: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 2022-01-27 08:30:08.291742: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 10/10 [==============================] - 9s 118ms/step - loss: 0.6793 - accuracy: 0.5047 - val_loss: 0.6399 - val_accuracy: 0.5188
# Epoch 2/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.6521 - accuracy: 0.5047 - val_loss: 0.6274 - val_accuracy: 0.5312
# Epoch 3/150
# 10/10 [==============================] - 1s 67ms/step - loss: 0.6308 - accuracy: 0.5047 - val_loss: 0.6123 - val_accuracy: 0.5188
# Epoch 4/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.6121 - accuracy: 0.5063 - val_loss: 0.6267 - val_accuracy: 0.5437
# Epoch 5/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6543 - accuracy: 0.5094 - val_loss: 0.6631 - val_accuracy: 0.6062
# Epoch 6/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6680 - accuracy: 0.5719 - val_loss: 0.6708 - val_accuracy: 0.7125
# Epoch 7/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6785 - accuracy: 0.6109 - val_loss: 0.6876 - val_accuracy: 0.5813
# Epoch 8/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6709 - accuracy: 0.5828 - val_loss: 0.6466 - val_accuracy: 0.5750
# Epoch 9/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6721 - accuracy: 0.5813 - val_loss: 0.6656 - val_accuracy: 0.7125
# Epoch 10/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.6804 - accuracy: 0.6250 - val_loss: 0.6827 - val_accuracy: 0.7375
# Epoch 11/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6675 - accuracy: 0.5781 - val_loss: 0.6250 - val_accuracy: 0.5375
# Epoch 12/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6392 - accuracy: 0.5641 - val_loss: 0.6517 - val_accuracy: 0.6313
# Epoch 13/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6466 - accuracy: 0.6281 - val_loss: 0.6447 - val_accuracy: 0.6062
# Epoch 14/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6226 - accuracy: 0.5500 - val_loss: 0.7219 - val_accuracy: 0.5188
# Epoch 15/150
# 10/10 [==============================] - 1s 69ms/step - loss: 0.6021 - accuracy: 0.5469 - val_loss: 0.6347 - val_accuracy: 0.5188
# Epoch 16/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.5805 - accuracy: 0.5594 - val_loss: 0.5871 - val_accuracy: 0.5562
# Epoch 17/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.5828 - accuracy: 0.5672 - val_loss: 0.5861 - val_accuracy: 0.5688
# Epoch 18/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5767 - accuracy: 0.6047 - val_loss: 0.5820 - val_accuracy: 0.5750
# Epoch 19/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5622 - accuracy: 0.6109 - val_loss: 0.5741 - val_accuracy: 0.6062
# Epoch 20/150
# 10/10 [==============================] - 1s 68ms/step - loss: 0.5761 - accuracy: 0.5719 - val_loss: 0.6073 - val_accuracy: 0.5813
# Epoch 21/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.5583 - accuracy: 0.6172 - val_loss: 0.5716 - val_accuracy: 0.6625
# Epoch 22/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5549 - accuracy: 0.6359 - val_loss: 0.6023 - val_accuracy: 0.6687
# Epoch 23/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5529 - accuracy: 0.6531 - val_loss: 0.5836 - val_accuracy: 0.6187
# Epoch 24/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5455 - accuracy: 0.6641 - val_loss: 0.5835 - val_accuracy: 0.6375
# Epoch 25/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.5394 - accuracy: 0.6766 - val_loss: 0.5747 - val_accuracy: 0.6062
# Epoch 26/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5417 - accuracy: 0.6625 - val_loss: 0.5803 - val_accuracy: 0.6375
# Epoch 27/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5179 - accuracy: 0.7063 - val_loss: 0.5792 - val_accuracy: 0.6438
# Epoch 28/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5323 - accuracy: 0.6656 - val_loss: 0.5559 - val_accuracy: 0.6687
# Epoch 29/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5127 - accuracy: 0.6938 - val_loss: 0.5479 - val_accuracy: 0.7063
# Epoch 30/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5199 - accuracy: 0.7109 - val_loss: 0.5441 - val_accuracy: 0.6562
# Epoch 31/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5401 - accuracy: 0.6687 - val_loss: 0.5764 - val_accuracy: 0.7125
# Epoch 32/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5198 - accuracy: 0.7594 - val_loss: 0.5630 - val_accuracy: 0.7812
# Epoch 33/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.5100 - accuracy: 0.7297 - val_loss: 0.5554 - val_accuracy: 0.7375
# Epoch 34/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4940 - accuracy: 0.7109 - val_loss: 0.6009 - val_accuracy: 0.6625
# Epoch 35/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5132 - accuracy: 0.7422 - val_loss: 0.5606 - val_accuracy: 0.7812
# Epoch 36/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.5006 - accuracy: 0.7391 - val_loss: 0.5746 - val_accuracy: 0.6438
# Epoch 37/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.4944 - accuracy: 0.7172 - val_loss: 0.5713 - val_accuracy: 0.6875
# Epoch 38/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4850 - accuracy: 0.7500 - val_loss: 0.5363 - val_accuracy: 0.7750
# Epoch 39/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4887 - accuracy: 0.7516 - val_loss: 0.5715 - val_accuracy: 0.6875
# Epoch 40/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4734 - accuracy: 0.7672 - val_loss: 0.5512 - val_accuracy: 0.6625
# Epoch 41/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4868 - accuracy: 0.7672 - val_loss: 0.5306 - val_accuracy: 0.7188
# Epoch 42/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4765 - accuracy: 0.7797 - val_loss: 0.5203 - val_accuracy: 0.7250
# Epoch 43/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.4833 - accuracy: 0.7609 - val_loss: 0.5120 - val_accuracy: 0.7812
# Epoch 44/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4670 - accuracy: 0.7953 - val_loss: 0.5352 - val_accuracy: 0.7125
# Epoch 45/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4585 - accuracy: 0.7891 - val_loss: 0.5491 - val_accuracy: 0.7188
# Epoch 46/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4432 - accuracy: 0.7859 - val_loss: 0.5871 - val_accuracy: 0.7188
# Epoch 47/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4408 - accuracy: 0.8219 - val_loss: 0.5395 - val_accuracy: 0.6938
# Epoch 48/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.4392 - accuracy: 0.8188 - val_loss: 0.5423 - val_accuracy: 0.7625
# Epoch 49/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4346 - accuracy: 0.7891 - val_loss: 0.5219 - val_accuracy: 0.7375
# Epoch 50/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4259 - accuracy: 0.8578 - val_loss: 0.5552 - val_accuracy: 0.7312
# Epoch 51/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.4595 - accuracy: 0.8125 - val_loss: 0.5116 - val_accuracy: 0.8062
# Epoch 52/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4675 - accuracy: 0.8188 - val_loss: 0.5929 - val_accuracy: 0.6875
# Epoch 53/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4589 - accuracy: 0.8203 - val_loss: 0.5208 - val_accuracy: 0.7625
# Epoch 54/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4504 - accuracy: 0.8188 - val_loss: 0.5077 - val_accuracy: 0.7625
# Epoch 55/150
# 10/10 [==============================] - 1s 69ms/step - loss: 0.4338 - accuracy: 0.8344 - val_loss: 0.5027 - val_accuracy: 0.8125
# Epoch 56/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.4161 - accuracy: 0.8500 - val_loss: 0.5418 - val_accuracy: 0.7312
# Epoch 57/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.4116 - accuracy: 0.8547 - val_loss: 0.5008 - val_accuracy: 0.7750
# Epoch 58/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3997 - accuracy: 0.8531 - val_loss: 0.5249 - val_accuracy: 0.7437
# Epoch 59/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4080 - accuracy: 0.8422 - val_loss: 0.4929 - val_accuracy: 0.7875
# Epoch 60/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3995 - accuracy: 0.8562 - val_loss: 0.5071 - val_accuracy: 0.7625
# Epoch 61/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3939 - accuracy: 0.8734 - val_loss: 0.4857 - val_accuracy: 0.7937
# Epoch 62/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3894 - accuracy: 0.8859 - val_loss: 0.5258 - val_accuracy: 0.7312
# Epoch 63/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3900 - accuracy: 0.8734 - val_loss: 0.5461 - val_accuracy: 0.7500
# Epoch 64/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.3813 - accuracy: 0.8750 - val_loss: 0.4700 - val_accuracy: 0.8000
# Epoch 65/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3708 - accuracy: 0.8875 - val_loss: 0.4236 - val_accuracy: 0.8625
# Epoch 66/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3674 - accuracy: 0.8906 - val_loss: 0.5259 - val_accuracy: 0.7812
# Epoch 67/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3694 - accuracy: 0.8813 - val_loss: 0.4373 - val_accuracy: 0.8313
# Epoch 68/150
# 10/10 [==============================] - 1s 68ms/step - loss: 0.3744 - accuracy: 0.9125 - val_loss: 0.4137 - val_accuracy: 0.8250
# Epoch 69/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3680 - accuracy: 0.8672 - val_loss: 0.5041 - val_accuracy: 0.7500
# Epoch 70/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3620 - accuracy: 0.8953 - val_loss: 0.5545 - val_accuracy: 0.7750
# Epoch 71/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3707 - accuracy: 0.8875 - val_loss: 0.4202 - val_accuracy: 0.8375
# Epoch 72/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.3724 - accuracy: 0.8828 - val_loss: 0.4259 - val_accuracy: 0.8250
# Epoch 73/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3568 - accuracy: 0.8875 - val_loss: 0.4684 - val_accuracy: 0.8375
# Epoch 74/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3519 - accuracy: 0.8984 - val_loss: 0.5574 - val_accuracy: 0.7688
# Epoch 75/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3516 - accuracy: 0.8938 - val_loss: 0.5166 - val_accuracy: 0.7937
# Epoch 76/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3428 - accuracy: 0.9047 - val_loss: 0.3897 - val_accuracy: 0.8500
# Epoch 77/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3358 - accuracy: 0.9062 - val_loss: 0.4363 - val_accuracy: 0.8438
# Epoch 78/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3328 - accuracy: 0.9203 - val_loss: 0.4518 - val_accuracy: 0.8250
# Epoch 79/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3180 - accuracy: 0.9250 - val_loss: 0.4249 - val_accuracy: 0.8750
# Epoch 80/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3211 - accuracy: 0.9312 - val_loss: 0.4053 - val_accuracy: 0.8500
# Epoch 81/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.3118 - accuracy: 0.9406 - val_loss: 0.3801 - val_accuracy: 0.8813
# Epoch 82/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3177 - accuracy: 0.9203 - val_loss: 0.3701 - val_accuracy: 0.8625
# Epoch 83/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3016 - accuracy: 0.9438 - val_loss: 0.5102 - val_accuracy: 0.8062
# Epoch 84/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3586 - accuracy: 0.8844 - val_loss: 0.4584 - val_accuracy: 0.8125
# Epoch 85/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3256 - accuracy: 0.9203 - val_loss: 0.3913 - val_accuracy: 0.8438
# Epoch 86/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3410 - accuracy: 0.9016 - val_loss: 0.4102 - val_accuracy: 0.8188
# Epoch 87/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3440 - accuracy: 0.9047 - val_loss: 0.4297 - val_accuracy: 0.8625
# Epoch 88/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3363 - accuracy: 0.9000 - val_loss: 0.4150 - val_accuracy: 0.8250
# Epoch 89/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.3237 - accuracy: 0.9375 - val_loss: 0.3967 - val_accuracy: 0.8500
# Epoch 90/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.3123 - accuracy: 0.9312 - val_loss: 0.3881 - val_accuracy: 0.8750
# Epoch 91/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2982 - accuracy: 0.9422 - val_loss: 0.3875 - val_accuracy: 0.8438
# Epoch 92/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2975 - accuracy: 0.9422 - val_loss: 0.3533 - val_accuracy: 0.9187
# Epoch 93/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2881 - accuracy: 0.9469 - val_loss: 0.3781 - val_accuracy: 0.8687
# Epoch 94/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2763 - accuracy: 0.9531 - val_loss: 0.3972 - val_accuracy: 0.8750
# Epoch 95/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2815 - accuracy: 0.9422 - val_loss: 0.3783 - val_accuracy: 0.8750
# Epoch 96/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2873 - accuracy: 0.9344 - val_loss: 0.4056 - val_accuracy: 0.8625
# Epoch 97/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.2808 - accuracy: 0.9453 - val_loss: 0.3832 - val_accuracy: 0.8562
# Epoch 98/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.2732 - accuracy: 0.9531 - val_loss: 0.3610 - val_accuracy: 0.8687
# Epoch 99/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2744 - accuracy: 0.9578 - val_loss: 0.3533 - val_accuracy: 0.8875
# Epoch 100/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2635 - accuracy: 0.9516 - val_loss: 0.3604 - val_accuracy: 0.8687
# Epoch 101/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2658 - accuracy: 0.9547 - val_loss: 0.5169 - val_accuracy: 0.7750
# Epoch 102/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3099 - accuracy: 0.9109 - val_loss: 0.4886 - val_accuracy: 0.7937
# Epoch 103/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2906 - accuracy: 0.9328 - val_loss: 0.4300 - val_accuracy: 0.8562
# Epoch 104/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2691 - accuracy: 0.9516 - val_loss: 0.3415 - val_accuracy: 0.8813
# Epoch 105/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2657 - accuracy: 0.9609 - val_loss: 0.3446 - val_accuracy: 0.9062
# Epoch 106/150
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2546 - accuracy: 0.9641 - val_loss: 0.3579 - val_accuracy: 0.8562
# Epoch 107/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2515 - accuracy: 0.9625 - val_loss: 0.3516 - val_accuracy: 0.8625
# Epoch 108/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2454 - accuracy: 0.9578 - val_loss: 0.3539 - val_accuracy: 0.8750
# Epoch 109/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2496 - accuracy: 0.9484 - val_loss: 0.3495 - val_accuracy: 0.8687
# Epoch 110/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2419 - accuracy: 0.9531 - val_loss: 0.3506 - val_accuracy: 0.8625
# Epoch 111/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2582 - accuracy: 0.9406 - val_loss: 0.3686 - val_accuracy: 0.8687
# Epoch 112/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2474 - accuracy: 0.9531 - val_loss: 0.3614 - val_accuracy: 0.8562
# Epoch 113/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2390 - accuracy: 0.9625 - val_loss: 0.3364 - val_accuracy: 0.8813
# Epoch 114/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2357 - accuracy: 0.9563 - val_loss: 0.3582 - val_accuracy: 0.8813
# Epoch 115/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2313 - accuracy: 0.9563 - val_loss: 0.3501 - val_accuracy: 0.8750
# Epoch 116/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2378 - accuracy: 0.9531 - val_loss: 0.3427 - val_accuracy: 0.8938
# Epoch 117/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2348 - accuracy: 0.9547 - val_loss: 0.3542 - val_accuracy: 0.8875
# Epoch 118/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2281 - accuracy: 0.9578 - val_loss: 0.3572 - val_accuracy: 0.8750
# Epoch 119/150
# 10/10 [==============================] - 1s 67ms/step - loss: 0.2371 - accuracy: 0.9531 - val_loss: 0.3595 - val_accuracy: 0.8813
# Epoch 120/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2267 - accuracy: 0.9594 - val_loss: 0.3698 - val_accuracy: 0.8500
# Epoch 121/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2214 - accuracy: 0.9688 - val_loss: 0.3697 - val_accuracy: 0.8625
# Epoch 122/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2166 - accuracy: 0.9641 - val_loss: 0.3615 - val_accuracy: 0.8687
# Epoch 123/150
# 10/10 [==============================] - 1s 67ms/step - loss: 0.2246 - accuracy: 0.9500 - val_loss: 0.3430 - val_accuracy: 0.8938
# Epoch 124/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2503 - accuracy: 0.9375 - val_loss: 0.5548 - val_accuracy: 0.7188
# Epoch 125/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.4095 - accuracy: 0.8375 - val_loss: 0.4950 - val_accuracy: 0.7937
# Epoch 126/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.4137 - accuracy: 0.8391 - val_loss: 0.5022 - val_accuracy: 0.7625
# Epoch 127/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3541 - accuracy: 0.8687 - val_loss: 0.3879 - val_accuracy: 0.8375
# Epoch 128/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2786 - accuracy: 0.9391 - val_loss: 0.3499 - val_accuracy: 0.8750
# Epoch 129/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2500 - accuracy: 0.9516 - val_loss: 0.3339 - val_accuracy: 0.8938
# Epoch 130/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2345 - accuracy: 0.9563 - val_loss: 0.3155 - val_accuracy: 0.9125
# Epoch 131/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2323 - accuracy: 0.9594 - val_loss: 0.3255 - val_accuracy: 0.8875
# Epoch 132/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2235 - accuracy: 0.9656 - val_loss: 0.3220 - val_accuracy: 0.9000
# Epoch 133/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2276 - accuracy: 0.9563 - val_loss: 0.3136 - val_accuracy: 0.9000
# Epoch 134/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2177 - accuracy: 0.9656 - val_loss: 0.3124 - val_accuracy: 0.8750
# Epoch 135/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2096 - accuracy: 0.9625 - val_loss: 0.3202 - val_accuracy: 0.8687
# Epoch 136/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2078 - accuracy: 0.9641 - val_loss: 0.3192 - val_accuracy: 0.8750
# Epoch 137/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2066 - accuracy: 0.9656 - val_loss: 0.3241 - val_accuracy: 0.8687
# Epoch 138/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2015 - accuracy: 0.9672 - val_loss: 0.3207 - val_accuracy: 0.8750
# Epoch 139/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1977 - accuracy: 0.9688 - val_loss: 0.3307 - val_accuracy: 0.8875
# Epoch 140/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.1970 - accuracy: 0.9625 - val_loss: 0.3256 - val_accuracy: 0.8750
# Epoch 141/150
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2053 - accuracy: 0.9578 - val_loss: 0.3384 - val_accuracy: 0.8687
# Epoch 142/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1955 - accuracy: 0.9656 - val_loss: 0.3487 - val_accuracy: 0.8562
# Epoch 143/150
# 10/10 [==============================] - 1s 66ms/step - loss: 0.1880 - accuracy: 0.9672 - val_loss: 0.3415 - val_accuracy: 0.8562
# Epoch 144/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1859 - accuracy: 0.9719 - val_loss: 0.3359 - val_accuracy: 0.8875
# Epoch 145/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1777 - accuracy: 0.9719 - val_loss: 0.3415 - val_accuracy: 0.8875
# Epoch 146/150
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1806 - accuracy: 0.9703 - val_loss: 0.3623 - val_accuracy: 0.8562
# Epoch 147/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1769 - accuracy: 0.9719 - val_loss: 0.3499 - val_accuracy: 0.8875
# Epoch 148/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1779 - accuracy: 0.9688 - val_loss: 0.3641 - val_accuracy: 0.8500
# Epoch 149/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1769 - accuracy: 0.9688 - val_loss: 0.3353 - val_accuracy: 0.8813
# Epoch 150/150
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2132 - accuracy: 0.9438 - val_loss: 0.3395 - val_accuracy: 0.8750

# %%
# Training Plot
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])

# %% [markdown]
# # Testing

# %%
def test_visualize(images, n = 5):
    """ Visualize a few images """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    axs = fig.subplots(1, n)
    for i in range(n):
        show(axs[i], images[i])

# %% [markdown]
# ## Test 1

# %%
test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

# %%
plt.imshow(test_image)

# %%
test_visualize(compare_images)

# %%
image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))

image_pairs = np.array(image_pairs)

# %%
score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])

# %%
print(score)
# Out:
# [[0.7926489 ]
#  [0.5802973 ]
#  [0.00151463]
#  [0.00240386]
#  [0.00457218]]

# %% [markdown]
# ## Test 2

# %%
test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10, 20), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

# %%
plt.imshow(test_image)

# %%
test_visualize(compare_images)

# %%
image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))

image_pairs = np.array(image_pairs)

# %%
score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])

# %%
print(score)
# Out:
# [[0.58032215]
#  [0.79100263]
#  [0.00134922]
#  [0.00216706]
#  [0.0042368 ]]
